# %% [markdown]
# ## Subplots features

# %%
import plotly.graph_objs as go
from plotly.subplots import make_subplots
import numpy as np

# %%
t = np.linspace(0, 6 * np.pi, 1001)
x = np.sin(t)
y = np.cos(t)

# %%
fig = make_subplots(shared_xaxes = True,
                    rows = 2, cols = 1,
                    x_title = '<b>Time</b>', 
                    y_title = '<b>Amplitude</b>', 
                    vertical_spacing = 0.07, 
                    column_widths = [5],
                    row_heights = [2, 3],
                    subplot_titles = ['<b>Sin Wave</b>', '<b>Cos Wave</b>'])

fig.add_trace(go.Scatter(x = t, y = x,
                         name = 'Sin Wave'),
              row = 1, col = 1)

fig.add_trace(go.Scatter(x = t, y = y,
                         name = 'Cos Wave'),
              row = 2, col = 1)

fig.update_xaxes(showline = True,
                 linewidth = 3,
                 linecolor = 'black',
                 mirror = True)
fig.update_yaxes(showline = True,
                 linewidth = 3,
                 linecolor = 'black',
                 mirror = True)

fig.update_layout(plot_bgcolor = 'rgba(255, 0, 255, .50)')
# Out:
# <div>
#
#
#             <div id="89abb1e3-7db1-47d0-b526-cc1562528887" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("89abb1e3-7db1-47d0-b526-cc1562528887")) {
#                     Plotly.newPlot(
#                         '89abb1e3-7db1-47d0-b526-cc1562528887',
# ...
